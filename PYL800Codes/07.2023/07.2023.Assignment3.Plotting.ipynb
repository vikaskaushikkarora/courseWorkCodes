# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import exp,sin,cos,pi

# %%
def a(r):
  return 2*r*cos(pi*54/180)

def b(r):
  return 2*r*cos(pi*36/180)*sin(pi*54/180)

A=1.0
k=0.1

def f(r):
  return A*(((exp(-k*r))/r)+((exp(-k*a(r)))/a(r))+((exp(-k*b(r)))/b(r))) + B*r*r

# %%
r=np.arange(-10,10,0.1)
plt.plot(r,f(r))
plt.ylim(-10,10)
plt.show()

# %%
r=np.arange(0.1,3,0.01)
plt.plot(r,f(r))
plt.grid()
plt.show()
